# %%
#IMPORTING THE REQUIRED LIBRARIES
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings('ignore')

# %%
#IMPORTING THE DATASET
ds1 = pd.read_csv('baseball.csv')
ds1
# Out:
#       W    R    AB     H   2B  3B   HR   BB    SO   SB   RA   ER   ERA  CG  \
# 0    95  724  5575  1497  300  42  139  383   973  104  641  601  3.73   2
# 1    83  696  5467  1349  277  44  156  439  1264   70  700  653  4.07   2
# 2    81  669  5439  1395  303  29  141  533  1157   86  640  584  3.67  11
# 3    76  622  5533  1381  260  27  136  404  1231   68  701  643  3.98   7
# 4    74  689  5605  1515  289  49  151  455  1259   83  803  746  4.64   7
# 5    93  891  5509  1480  308  17  232  570  1151   88  670  609  3.80   7
# 6    87  764  5567  1397  272  19  212  554  1227   63  698  652  4.03   3
# 7    81  713  5485  1370  246  20  217  418  1331   44  693  646  4.05   0
# 8    80  644  5485  1383  278  32  167  436  1310   87  642  604  3.74   1
# 9    78  748  5640  1495  294  33  161  478  1148   71  753  694  4.31   3
# 10   88  751  5511  1419  279  32  172  503  1233  101  733  680  4.24   5
# ...

# %%
ds1.shape
# Out:
# (30, 17)

# %%
#CHECHING FOR THE DATA TYPES OF EACH COLUMN
ds1.dtypes
# Out:
# W        int64
# R        int64
# AB       int64
# H        int64
# 2B       int64
# 3B       int64
# HR       int64
# BB       int64
# SO       int64
# SB       int64
# RA       int64
# ER       int64
# ERA    float64
# CG       int64
# SHO      int64
# SV       int64
# E        int64
# dtype: object

# %%
#CHECKING FOR NULL VALUES
ds1.isnull().sum()
# Out:
# W      0
# R      0
# AB     0
# H      0
# 2B     0
# 3B     0
# HR     0
# BB     0
# SO     0
# SB     0
# RA     0
# ER     0
# ERA    0
# CG     0
# SHO    0
# SV     0
# E      0
# dtype: int64

# %%
#CHECKING FOR THE COUNT OF EVERY VALUES IN EACH COULMNS
for i in ds1.columns: 
    print(ds1[i].value_counts())
# Out:
# 68     3
# 81     2
# 76     2
# 74     2
# 83     2
# 98     1
# 84     1
# 92     1
# 63     1
# 67     1
# 71     1
# 90     1
# 64     1
# 97     1
# 95     1
# 100    1
# 85     1
# 86     1
# 88     1
# 78     1
# 80     1
# 87     1
# 93     1
# 79     1
# Name: W, dtype: int64
# 689    2
# 696    2
# 724    1
# 647    1
# 650    1
# 720    1
# 667    1
# 626    1
# 573    1
# 613    1
# 703    1
# 683    1
# 640    1
# 655    1
# 697    1
# 694    1
# 656    1
# 661    1
# 729    1
# 751    1
# 748    1
# 644    1
# 713    1
# 764    1
# 891    1
# 622    1
# 669    1
# 737    1
# Name: R, dtype: int64
# 5485    2
# 5575    1
# 5631    1
# 5457    1
# 5649    1
# 5565    1
# 5385    1
# 5529    1
# 5420    1
# 5463    1
# 5428    1
# 5527    1
# 5571    1
# 5480    1
# 5491    1
# 5484    1
# 5467    1
# 5600    1
# 5544    1
# 5417    1
# 5459    1
# 5511    1
# 5640    1
# 5567    1
# 5509    1
# 5605    1
# 5533    1
# 5439    1
# 5572    1
# Name: AB, dtype: int64
# ...

# %%
ds1.nunique()
# Out:
# W      24
# R      28
# AB     29
# H      29
# 2B     22
# 3B     23
# HR     27
# BB     29
# SO     29
# SB     27
# RA     30
# ER     30
# ERA    30
# CG      9
# SHO    12
# SV     20
# E      21
# dtype: int64

# %%
ds1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 30 entries, 0 to 29
# Data columns (total 17 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   W       30 non-null     int64
#  1   R       30 non-null     int64
#  2   AB      30 non-null     int64
#  3   H       30 non-null     int64
#  4   2B      30 non-null     int64
#  5   3B      30 non-null     int64
#  6   HR      30 non-null     int64
#  7   BB      30 non-null     int64
#  8   SO      30 non-null     int64
#  9   SB      30 non-null     int64
#  10  RA      30 non-null     int64
#  11  ER      30 non-null     int64
#  12  ERA     30 non-null     float64
#  13  CG      30 non-null     int64
#  14  SHO     30 non-null     int64
#  15  SV      30 non-null     int64
#  16  E       30 non-null     int64
# dtypes: float64(1), int64(16)
# memory usage: 4.1 KB

# %% [markdown]
# # STATISTICAL ANALYSIS

# %%
ds1.describe()
# Out:
#                 W           R           AB            H          2B  \
# count   30.000000   30.000000    30.000000    30.000000   30.000000
# mean    80.966667  688.233333  5516.266667  1403.533333  274.733333
# std     10.453455   58.761754    70.467372    57.140923   18.095405
# min     63.000000  573.000000  5385.000000  1324.000000  236.000000
# 25%     74.000000  651.250000  5464.000000  1363.000000  262.250000
# 50%     81.000000  689.000000  5510.000000  1382.500000  275.500000
# 75%     87.750000  718.250000  5570.000000  1451.500000  288.750000
# max    100.000000  891.000000  5649.000000  1515.000000  308.000000
#
#               3B          HR          BB          SO          SB          RA  \
# count  30.000000   30.000000   30.000000    30.00000   30.000000   30.000000
# mean   31.300000  163.633333  469.100000  1248.20000   83.500000  688.233333
# std    10.452355   31.823309   57.053725   103.75947   22.815225   72.108005
# ...

# %% [markdown]
# From the above output We can infer that
#
#     - There are no null values in the data set
#     - In most of the columns the mean value and the median value are almost equal and so the chance for skewness is less
#     - Also there is huge difference between the 75% and the max values are less in most of the columns and the chance for the outliers are also less

# %%
sns.regplot(x='R',y='W',data=ds1)
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %% [markdown]
# Runs and wins are linearly correleted

# %%
sns.regplot(x='AB',y='W',data=ds1)
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %% [markdown]
# From the above plot it is clear that there is no correlation between "At Bat"and Wins

# %%
sns.regplot(x='H',y='W',data=ds1)
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %% [markdown]
# Also there is no correlation between hits and wins

# %%
sns.regplot(x='2B',y='W',data=ds1)
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %% [markdown]
# Doubles are linearly correleated with wins

# %%
sns.regplot(x='3B',y='W',data=ds1)
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %% [markdown]
# Triples are some what negatively correleted with wins

# %%
sns.regplot(x='HR',y='W',data=ds1)
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %% [markdown]
# Home Runs have very low positive correletion with wins

# %%
sns.regplot(x='BB',y='W',data=ds1)
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %% [markdown]
# Base on balls low positive correletion with wins

# %%
sns.regplot(x='SO',y='W',data=ds1)
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %% [markdown]
# There is no correletion between Strikeout and Wins

# %%
sns.regplot(x='ER',y='W',data=ds1)
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %% [markdown]
# Earned Runs have high negative correletion with wins

# %%
sns.regplot(x='ERA',y='W',data=ds1)
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %% [markdown]
# Earned Average Runs have high negative correletion with wins

# %%
sns.regplot(x='CG',y='W',data=ds1)
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %% [markdown]
# CG is not correleted with the Target Wins

# %%
sns.regplot(x='SHO',y='W',data=ds1)
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %% [markdown]
# Shut out have high positive correletion with Wins

# %%
sns.regplot(x='SV',y='W',data=ds1)
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %% [markdown]
# Saves are positively correleted with wins

# %%
sns.regplot(x='E',y='W',data=ds1)
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %% [markdown]
# Errors are not correleted with wins

# %%
#CHECKING FOR OUTLIERS
ds1.plot(kind='box',subplots=True,figsize=(10,10),layout=(5,4))
# Out:
# W         AxesSubplot(0.125,0.747241;0.168478x0.132759)
# R      AxesSubplot(0.327174,0.747241;0.168478x0.132759)
# AB     AxesSubplot(0.529348,0.747241;0.168478x0.132759)
# H      AxesSubplot(0.731522,0.747241;0.168478x0.132759)
# 2B        AxesSubplot(0.125,0.587931;0.168478x0.132759)
# 3B     AxesSubplot(0.327174,0.587931;0.168478x0.132759)
# HR     AxesSubplot(0.529348,0.587931;0.168478x0.132759)
# BB     AxesSubplot(0.731522,0.587931;0.168478x0.132759)
# SO        AxesSubplot(0.125,0.428621;0.168478x0.132759)
# SB     AxesSubplot(0.327174,0.428621;0.168478x0.132759)
# RA     AxesSubplot(0.529348,0.428621;0.168478x0.132759)
# ER     AxesSubplot(0.731522,0.428621;0.168478x0.132759)
# ERA        AxesSubplot(0.125,0.26931;0.168478x0.132759)
# CG      AxesSubplot(0.327174,0.26931;0.168478x0.132759)
# SHO     AxesSubplot(0.529348,0.26931;0.168478x0.132759)
# SV      AxesSubplot(0.731522,0.26931;0.168478x0.132759)
# E             AxesSubplot(0.125,0.11;0.168478x0.132759)
# ...

# %% [markdown]
# From the above box plots we can infer that the data set is free from outliers

# %%
#SEPERATING INDEPENDENT VARIABLES AND TARGET
x1 = ds1.drop('W',axis=1)
y1 = ds1['W']
print(x1)
# Out:
#       R    AB     H   2B  3B   HR   BB    SO   SB   RA   ER   ERA  CG  SHO  \
# 0   724  5575  1497  300  42  139  383   973  104  641  601  3.73   2    8
# 1   696  5467  1349  277  44  156  439  1264   70  700  653  4.07   2   12
# 2   669  5439  1395  303  29  141  533  1157   86  640  584  3.67  11   10
# 3   622  5533  1381  260  27  136  404  1231   68  701  643  3.98   7    9
# 4   689  5605  1515  289  49  151  455  1259   83  803  746  4.64   7   12
# 5   891  5509  1480  308  17  232  570  1151   88  670  609  3.80   7   10
# 6   764  5567  1397  272  19  212  554  1227   63  698  652  4.03   3    4
# 7   713  5485  1370  246  20  217  418  1331   44  693  646  4.05   0   10
# 8   644  5485  1383  278  32  167  436  1310   87  642  604  3.74   1   12
# 9   748  5640  1495  294  33  161  478  1148   71  753  694  4.31   3   10
# 10  751  5511  1419  279  32  172  503  1233  101  733  680  4.24   5    9
# ...

# %%
y1
# Out:
# 0      95
# 1      83
# 2      81
# 3      76
# 4      74
# 5      93
# 6      87
# 7      81
# 8      80
# 9      78
# 10     88
# 11     86
# 12     85
# 13     76
# 14     68
# 15    100
# 16     98
# 17     97
# 18     68
# 19     64
# 20     90
# 21     83
# 22     71
# 23     67
# 24     63
# 25     92
# 26     84
# 27     79
# 28     74
# 29     68
# Name: W, dtype: int64

# %%
#SCALING TO REMOVE BIASNESS - STANDARD SCALING
from sklearn.preprocessing import StandardScaler
st=StandardScaler()
x1=st.fit_transform(x1)
x1
# Out:
# array([[ 0.61907797,  0.84773126,  1.66368512,  1.42017307,  1.04119304,
#         -0.7872986 , -1.53490242, -2.69762957,  0.91388329, -0.66623393,
#         -0.50511008, -0.50695519, -0.5398062 , -0.81462859,  1.67160651,
#         -0.46146963],
#        [ 0.13443166, -0.71109353, -0.97068076,  0.12740339,  1.23580856,
#         -0.24396668, -0.5365919 ,  0.15487844, -0.60182558,  0.16597077,
#          0.24892985,  0.25459752, -0.5398062 ,  0.1728    ,  0.24987932,
#         -0.60719689],
#        [-0.33290586, -1.1152333 , -0.15189137,  1.58879521, -0.22380785,
#         -0.7233772 ,  1.13914361, -0.89398189,  0.11144918, -0.68033909,
#         -0.75162313, -0.64134684,  2.77264091, -0.32091429, -0.65485616,
#         -1.11724227],
#        [-1.14641931,  0.24152162, -0.40108814, -0.82812203, -0.41842337,
#         -0.8831807 , -1.16053598, -0.16860185, -0.69098493,  0.18007593,
#          0.10392217,  0.05301004,  1.3004422 , -0.56777144, -0.78410408,
#          0.48575751],
# ...

# %%
x1=pd.DataFrame(data=x1)
x1
# Out:
#           0         1         2         3         4         5         6   \
# 0   0.619078  0.847731  1.663685  1.420173  1.041193 -0.787299 -1.534902
# 1   0.134432 -0.711094 -0.970681  0.127403  1.235809 -0.243967 -0.536592
# 2  -0.332906 -1.115233 -0.151891  1.588795 -0.223808 -0.723377  1.139144
# 3  -1.146419  0.241522 -0.401088 -0.828122 -0.418423 -0.883181 -1.160536
# 4   0.013270  1.280738  1.984081  0.801892  1.722347 -0.403770 -0.251360
# 5   3.509647 -0.104884  1.361089  1.869832 -1.391501  2.185047  1.798742
# 6   1.311430  0.732263 -0.116292 -0.153633 -1.196885  1.545833  1.513510
# 7   0.428681 -0.451289 -0.596886 -1.615025 -1.099578  1.705636 -0.910958
# 8  -0.765626 -0.451289 -0.365489  0.183611  0.068115  0.107601 -0.590073
# 9   1.034489  1.785913  1.628086  1.082929  0.165423 -0.084163  0.158660
# 10  1.086415 -0.076017  0.275303  0.239818  0.068115  0.267405  0.604334
# 11  0.705622 -0.826562 -0.721484  0.183611 -0.515731  2.121125  0.301276
# ...

# %%
plt.figure(figsize=(15,6))
sns.heatmap(ds1.corr(),annot=True,linewidths=0.6,linecolor='black',fmt='0.2f')
plt.show()

# %% [markdown]
# From the above plot we can infer that multicollinearity problem exist in this dataset

# %%
from statsmodels.stats.outliers_influence import variance_inflation_factor
vif = pd.DataFrame()
vif["VIF Factor"] = [variance_inflation_factor(x1.values, i) for i in range(x1.shape[1])]
vif["features"] = x1.columns
vif
# Out:
#      VIF Factor  features
# 0     11.522370         0
# 1     13.311532         1
# 2     10.070668         2
# 3      4.019297         3
# 4      3.294146         4
# 5     10.079902         5
# 6      3.806098         6
# 7      2.652401         7
# 8      2.102684         8
# 9    191.839155         9
# 10  1680.387145        10
# 11  1222.722240        11
# 12     3.059904        12
# 13     3.654331        13
# 14     5.798850        14
# 15     2.186219        15

# %%
x11=x1.drop(x1.columns[[10]],axis=1)
x11
# Out:
#           0         1         2         3         4         5         6   \
# 0   0.619078  0.847731  1.663685  1.420173  1.041193 -0.787299 -1.534902
# 1   0.134432 -0.711094 -0.970681  0.127403  1.235809 -0.243967 -0.536592
# 2  -0.332906 -1.115233 -0.151891  1.588795 -0.223808 -0.723377  1.139144
# 3  -1.146419  0.241522 -0.401088 -0.828122 -0.418423 -0.883181 -1.160536
# 4   0.013270  1.280738  1.984081  0.801892  1.722347 -0.403770 -0.251360
# 5   3.509647 -0.104884  1.361089  1.869832 -1.391501  2.185047  1.798742
# 6   1.311430  0.732263 -0.116292 -0.153633 -1.196885  1.545833  1.513510
# 7   0.428681 -0.451289 -0.596886 -1.615025 -1.099578  1.705636 -0.910958
# 8  -0.765626 -0.451289 -0.365489  0.183611  0.068115  0.107601 -0.590073
# 9   1.034489  1.785913  1.628086  1.082929  0.165423 -0.084163  0.158660
# 10  1.086415 -0.076017  0.275303  0.239818  0.068115  0.267405  0.604334
# 11  0.705622 -0.826562 -0.721484  0.183611 -0.515731  2.121125  0.301276
# ...

# %%
from statsmodels.stats.outliers_influence import variance_inflation_factor
vif = pd.DataFrame()
vif["VIF Factor"] = [variance_inflation_factor(x11.values, i) for i in range(x11.shape[1])]
vif["features"] = x11.columns
vif
# Out:
#     VIF Factor  features
# 0    11.158733         0
# 1     5.863764         1
# 2     9.628749         2
# 3     3.786446         3
# 4     3.293109         4
# 5     9.057309         5
# 6     3.791451         6
# 7     2.607389         7
# 8     1.849280         8
# 9   122.133235         9
# 10  119.328698        11
# 11    2.741188        12
# 12    3.410561        13
# 13    3.203815        14
# 14    2.107345        15

# %%
x12=x11.drop(x11.columns[[9]],axis=1)
x12
# Out:
#           0         1         2         3         4         5         6   \
# 0   0.619078  0.847731  1.663685  1.420173  1.041193 -0.787299 -1.534902
# 1   0.134432 -0.711094 -0.970681  0.127403  1.235809 -0.243967 -0.536592
# 2  -0.332906 -1.115233 -0.151891  1.588795 -0.223808 -0.723377  1.139144
# 3  -1.146419  0.241522 -0.401088 -0.828122 -0.418423 -0.883181 -1.160536
# 4   0.013270  1.280738  1.984081  0.801892  1.722347 -0.403770 -0.251360
# 5   3.509647 -0.104884  1.361089  1.869832 -1.391501  2.185047  1.798742
# 6   1.311430  0.732263 -0.116292 -0.153633 -1.196885  1.545833  1.513510
# 7   0.428681 -0.451289 -0.596886 -1.615025 -1.099578  1.705636 -0.910958
# 8  -0.765626 -0.451289 -0.365489  0.183611  0.068115  0.107601 -0.590073
# 9   1.034489  1.785913  1.628086  1.082929  0.165423 -0.084163  0.158660
# 10  1.086415 -0.076017  0.275303  0.239818  0.068115  0.267405  0.604334
# 11  0.705622 -0.826562 -0.721484  0.183611 -0.515731  2.121125  0.301276
# ...

# %%
from statsmodels.stats.outliers_influence import variance_inflation_factor
vif = pd.DataFrame()
vif["VIF Factor"] = [variance_inflation_factor(x12.values, i) for i in range(x12.shape[1])]
vif["features"] = x12.columns
vif
# Out:
#     VIF Factor  features
# 0    10.987898         0
# 1     4.399954         1
# 2     8.941874         2
# 3     3.729413         3
# 4     3.142717         4
# 5     7.882841         5
# 6     3.468244         6
# 7     2.155496         7
# 8     1.819823         8
# 9     4.951981        11
# 10    2.723370        12
# 11    3.227759        13
# 12    2.948133        14
# 13    2.040676        15

# %% [markdown]
# Now the multicolinearity problem has been sorted out

# %% [markdown]
# MODELLING

# %%
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_absolute_error
from sklearn.metrics import mean_squared_error
from sklearn.metrics import r2_score

# %%
x=x12
y=y1

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.3,random_state=42)

# %%
#LINEAR REGRESSION
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import cross_val_score,KFold
m1=LinearRegression()
m1.fit(x_train,y_train)
trainprediction1=m1.predict(x_train)
print(r2_score(y_train,trainprediction1))
testprediction1=m1.predict(x_test)
print(r2_score(y_test,testprediction1))
kfold=KFold(n_splits=5,shuffle=True)
score1=cross_val_score(m1,x,y,cv=kfold)
print(score1)
print(score1.mean())
print((r2_score(y_test,testprediction1)-(score1.mean())))
# Out:
# 0.9690481416233611
# 0.8173794151132201
# [0.26137983 0.70326066 0.70337132 0.76250705 0.39026646]
# 0.5641570638627511
# 0.253222351250469

# %%
#ADA BOOST REGRESSION
from sklearn.ensemble import AdaBoostRegressor
m2=AdaBoostRegressor()
m2.fit(x_train,y_train)
trainprediction2=m2.predict(x_train)
print(r2_score(y_train,trainprediction2))
testprediction2=m2.predict(x_test)
print(r2_score(y_test,testprediction2))
kfold=KFold(n_splits=5,shuffle=True)
score2=cross_val_score(m2,x,y,cv=kfold)
print(score2)
print(score2.mean())
print((r2_score(y_test,testprediction2)-(score2.mean())))
# Out:
# 0.9952869945675157
# 0.6231575916945437
# [0.79841244 0.43002095 0.62310606 0.75415224 0.18954199]
# 0.5590467367611289
# 0.06411085493341473

# %%
#RANDOM FOREST REGRESSION
from sklearn.ensemble import RandomForestRegressor
m4=RandomForestRegressor()
m4.fit(x_train,y_train)
trainprediction4=m4.predict(x_train)
print(r2_score(y_train,trainprediction4))
testprediction4=m4.predict(x_test)
print(r2_score(y_test,testprediction4))
kfold=KFold(n_splits=5,shuffle=True)
score4=cross_val_score(m4,x,y,cv=kfold)
print(score4)
print(score4.mean())
print((r2_score(y_test,testprediction4)-(score4.mean())))
# Out:
# 0.9030642602712988
# 0.6257361386138611
# [0.64009406 0.54326925 0.78932651 0.38854638 0.71998173]
# 0.6162435833258563
# 0.009492555288004856

# %%
from sklearn.linear_model import BayesianRidge
model=BayesianRidge()
model.fit(x_train,y_train)
trainprediction=model.predict(x_train)
print(r2_score(y_train,trainprediction))
testprediction=model.predict(x_test)
print(r2_score(y_test,testprediction))
kfold=KFold(n_splits=5,shuffle=True)
score111=cross_val_score(model,x,y,cv=kfold)
print(score111)
print(score111.mean())
print((r2_score(y_test,testprediction1)-(score111.mean())))
# Out:
# 0.953771636122816
# 0.8249119100385914
# [0.82615288 0.10656814 0.94799595 0.74007279 0.71231486]
# 0.6666209237502685
# 0.1507584913629516

# %%
from sklearn.linear_model import Ridge
ridge=Ridge(alpha=10,max_iter=1000,tol=0.1)
ridge.fit(x_train,y_train)
trainprediction11=ridge.predict(x_train)
print(r2_score(y_train,trainprediction11))
testprediction11=ridge.predict(x_test)
print(r2_score(y_test,testprediction11))
kfold=KFold(n_splits=5,shuffle=True)
score22=cross_val_score(ridge,x,y,cv=kfold)
print(score22)
print(score22.mean())
print((r2_score(y1_test,testprediction11)-(score22.mean())))
# Out:
# 0.8807334732942205
# 0.7675419313869332
# [0.7974043  0.47600156 0.80789832 0.69627972 0.70488697]
# 0.6964941715798748
# 0.07104775980705835

# %%
from sklearn.linear_model import Lasso
lasso=Lasso(alpha=0.0001,max_iter=1000,tol=0.1)
lasso.fit(x_train,y_train)
trainprediction666=lasso.predict(x_train)
print(r2_score(y_train,trainprediction666))
testprediction666=lasso.predict(x_test)
print(r2_score(y_test,testprediction666))
kfold=KFold(n_splits=5,shuffle=True)
score666=cross_val_score(lasso,x,y,cv=kfold)
print(score666)
print(score666.mean())
print((r2_score(y_test,testprediction666)-(score666.mean())))
# Out:
# 0.9573531000886016
# 0.8070903727498966
# [0.56801844 0.90387136 0.25002935 0.69165424 0.78642881]
# 0.6400004401680361
# 0.16708993258186045

# %%
From the above models Ridge is selected as the best model based on the R2 score and the cross validation score

# %%
from sklearn.model_selection import GridSearchCV
parameters={'fit_intercept':[True,False],'copy_X':[True,False],'solver':['auto','svd','cholesky','lsqr','sag','saga','lbfgs','sparse_cg']}
gridsearchcv=GridSearchCV(Ridge(),parameters,cv=5)
gridsearchcv.fit(x_train,y_train)
# Out:
# GridSearchCV(cv=5, estimator=Ridge(),
#              param_grid={'copy_X': [True, False],
#                          'fit_intercept': [True, False],
#                          'solver': ['auto', 'svd', 'cholesky', 'lsqr', 'sag',
#                                     'saga', 'lbfgs', 'sparse_cg']})

# %%
gridsearchcv.best_params_
# Out:
# {'copy_X': False, 'fit_intercept': True, 'solver': 'saga'}

# %%
best_model=Ridge(copy_X=False,fit_intercept=True,solver='saga')
best_model.fit(x_train,y_train)
prediction=best_model.predict(x_test)
print(r2_score(y_test,prediction))
# Out:
# 0.8275832401527057

# %%
#SAVING THE BEST MODEL
import joblib
joblib.dump(best_model,"baseball.obj")
# Out:
# ['baseball.obj']

# %%
reload=joblib.load('baseball.obj')
reload.predict(x_test)
# Out:
# array([ 82.69510488, 102.18184698,  69.13195916,  92.17878811,
#         91.84668465,  79.98260771,  72.79276821,  61.6503991 ,
#         81.09974092])

# %%
def predict(baseball):
    baseball=baseball.reshape(1,-1)
    pred=best_model.predict(baseball)
    print(pred)
baseball=np.array([0.619078,0.847731,1.663685,1.420173,1.041193,-0.787299,-1.534902,-2.697630,0.913883,-0.506955,-0.539806,-0.814629,1.671607,-0.461470])
predict(baseball)
# Out:
# [95.34396231]
