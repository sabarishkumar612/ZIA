# %%
#IMPORTING THE REQUIRED LIBRARIES
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings('ignore')

# %%
#IMPORTING THE DATASET
ds1 = pd.read_csv('https://raw.githubusercontent.com/dsrscientist/dataset3/main/glass.csv',header=None)
ds1.columns=['ID','RI','Na','Mg','Al','Si','K','Ca','Ba','Fe','Type']
ds1
# Out:
#       ID       RI     Na    Mg    Al     Si     K    Ca    Ba   Fe  Type
# 0      1  1.52101  13.64  4.49  1.10  71.78  0.06  8.75  0.00  0.0     1
# 1      2  1.51761  13.89  3.60  1.36  72.73  0.48  7.83  0.00  0.0     1
# 2      3  1.51618  13.53  3.55  1.54  72.99  0.39  7.78  0.00  0.0     1
# 3      4  1.51766  13.21  3.69  1.29  72.61  0.57  8.22  0.00  0.0     1
# 4      5  1.51742  13.27  3.62  1.24  73.08  0.55  8.07  0.00  0.0     1
# ..   ...      ...    ...   ...   ...    ...   ...   ...   ...  ...   ...
# 209  210  1.51623  14.14  0.00  2.88  72.61  0.08  9.18  1.06  0.0     7
# 210  211  1.51685  14.92  0.00  1.99  73.06  0.00  8.40  1.59  0.0     7
# 211  212  1.52065  14.36  0.00  2.02  73.42  0.00  8.44  1.64  0.0     7
# 212  213  1.51651  14.38  0.00  1.94  73.61  0.00  8.48  1.57  0.0     7
# 213  214  1.51711  14.23  0.00  2.08  73.36  0.00  8.62  1.67  0.0     7
#
# [214 rows x 11 columns]

# %%
ds1.shape
# Out:
# (214, 11)

# %%
#CHECHING FOR THE DATA TYPES OF EACH COLUMN
ds1.dtypes
# Out:
# ID        int64
# RI      float64
# Na      float64
# Mg      float64
# Al      float64
# Si      float64
# K       float64
# Ca      float64
# Ba      float64
# Fe      float64
# Type      int64
# dtype: object

# %%
#CHECKING FOR NULL VALUES
ds1.isnull().sum()
# Out:
# ID      0
# RI      0
# Na      0
# Mg      0
# Al      0
# Si      0
# K       0
# Ca      0
# Ba      0
# Fe      0
# Type    0
# dtype: int64

# %% [markdown]
# So from the above output it is clear that there are three columns in which null values are there in the dataset

# %%
ds1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 214 entries, 0 to 213
# Data columns (total 11 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   ID      214 non-null    int64
#  1   RI      214 non-null    float64
#  2   Na      214 non-null    float64
#  3   Mg      214 non-null    float64
#  4   Al      214 non-null    float64
#  5   Si      214 non-null    float64
#  6   K       214 non-null    float64
#  7   Ca      214 non-null    float64
#  8   Ba      214 non-null    float64
#  9   Fe      214 non-null    float64
#  10  Type    214 non-null    int64
# dtypes: float64(9), int64(2)
# memory usage: 18.5 KB

# %%
#CHECKING FOR THE COUNT OF EVERY VALUES IN EACH COULMNS
for i in ds1.columns:
    print(ds1[i].value_counts())
# Out:
# 1      1
# 135    1
# 137    1
# 138    1
# 139    1
#       ..
# 75     1
# 76     1
# 77     1
# 78     1
# 214    1
# Name: ID, Length: 214, dtype: int64
# 1.52152    3
# 1.51590    3
# 1.51645    3
# 1.51754    2
# 1.51841    2
#           ..
# 1.51625    1
# 1.51569    1
# 1.51605    1
# 1.51588    1
# 1.51651    1
# Name: RI, Length: 178, dtype: int64
# 13.02    5
# 13.21    5
# 13.00    5
# 13.64    4
# 13.33    4
#         ..
# 13.34    1
# 13.31    1
# 14.17    1
# 13.51    1
# 14.23    1
# Name: Na, Length: 142, dtype: int64
# 0.00    42
# 3.48     8
# 3.58     8
# 3.54     8
# 3.52     7
#         ..
# 2.76     1
# 3.15     1
# 2.90     1
# 3.83     1
# 1.78     1
# Name: Mg, Length: 94, dtype: int64
# 1.54    8
# 1.19    6
# 1.43    5
# 1.29    5
# 1.23    5
#        ..
# 1.08    1
# 1.64    1
# 1.61    1
# 1.07    1
# 1.94    1
# Name: Al, Length: 118, dtype: int64
# 72.86    4
# 72.99    4
# 73.10    4
# 73.28    4
# 73.11    4
#         ..
# 73.55    1
# 72.34    1
# 72.26    1
# 73.26    1
# 73.61    1
# Name: Si, Length: 133, dtype: int64
# 0.00    30
# 0.57    12
# 0.56    11
# 0.60    11
# 0.58    10
#         ..
# 0.44     1
# 0.07     1
# 0.73     1
# 0.70     1
# 1.41     1
# Name: K, Length: 65, dtype: int64
# 8.03    5
# 8.43    5
# 9.57    4
# 8.79    4
# 8.44    4
#        ..
# 9.23    1
# 8.90    1
# 9.13    1
# 8.09    1
# 8.62    1
# Name: Ca, Length: 143, dtype: int64
# 0.00    176
# 0.64      2
# 1.57      2
# 0.09      2
# 1.59      2
# 0.11      2
# 3.15      1
# 0.81      1
# 1.64      1
# 1.06      1
# 0.54      1
# 2.88      1
# 1.38      1
# 1.55      1
# 0.67      1
# 1.71      1
# 0.56      1
# 0.63      1
# 0.53      1
# 0.66      1
# 0.61      1
# 0.27      1
# 0.69      1
# 0.40      1
# 0.14      1
# 0.76      1
# 1.68      1
# 1.63      1
# 1.19      1
# 0.24      1
# 2.20      1
# 0.15      1
# 0.06      1
# 1.67      1
# Name: Ba, dtype: int64
# 0.00    144
# 0.24      7
# 0.17      7
# 0.09      6
# 0.10      5
# 0.11      4
# 0.16      3
# 0.28      3
# 0.12      3
# 0.22      3
# 0.14      3
# 0.07      3
# 0.19      2
# 0.15      2
# 0.08      2
# 0.06      1
# 0.21      1
# 0.05      1
# 0.51      1
# 0.37      1
# 0.35      1
# 0.25      1
# 0.18      1
# 0.34      1
# 0.29      1
# 0.30      1
# 0.20      1
# 0.32      1
# 0.26      1
# 0.03      1
# 0.31      1
# 0.01      1
# Name: Fe, dtype: int64
# 2    76
# 1    70
# 7    29
# 3    17
# 5    13
# 6     9
# Name: Type, dtype: int64

# %%
ds1.nunique()
# Out:
# ID      214
# RI      178
# Na      142
# Mg       94
# Al      118
# Si      133
# K        65
# Ca      143
# Ba       34
# Fe       32
# Type      6
# dtype: int64

# %%
ds1=ds1.drop(columns=['ID'],axis=1)
ds1
# Out:
#           RI     Na    Mg    Al     Si     K    Ca    Ba   Fe  Type
# 0    1.52101  13.64  4.49  1.10  71.78  0.06  8.75  0.00  0.0     1
# 1    1.51761  13.89  3.60  1.36  72.73  0.48  7.83  0.00  0.0     1
# 2    1.51618  13.53  3.55  1.54  72.99  0.39  7.78  0.00  0.0     1
# 3    1.51766  13.21  3.69  1.29  72.61  0.57  8.22  0.00  0.0     1
# 4    1.51742  13.27  3.62  1.24  73.08  0.55  8.07  0.00  0.0     1
# ..       ...    ...   ...   ...    ...   ...   ...   ...  ...   ...
# 209  1.51623  14.14  0.00  2.88  72.61  0.08  9.18  1.06  0.0     7
# 210  1.51685  14.92  0.00  1.99  73.06  0.00  8.40  1.59  0.0     7
# 211  1.52065  14.36  0.00  2.02  73.42  0.00  8.44  1.64  0.0     7
# 212  1.51651  14.38  0.00  1.94  73.61  0.00  8.48  1.57  0.0     7
# 213  1.51711  14.23  0.00  2.08  73.36  0.00  8.62  1.67  0.0     7
#
# [214 rows x 10 columns]

# %% [markdown]
# # STATISTICAL ANALYSIS

# %%
ds1.describe()
# Out:
#                RI          Na          Mg          Al          Si           K  \
# count  214.000000  214.000000  214.000000  214.000000  214.000000  214.000000
# mean     1.518365   13.407850    2.684533    1.444907   72.650935    0.497056
# std      0.003037    0.816604    1.442408    0.499270    0.774546    0.652192
# min      1.511150   10.730000    0.000000    0.290000   69.810000    0.000000
# 25%      1.516522   12.907500    2.115000    1.190000   72.280000    0.122500
# 50%      1.517680   13.300000    3.480000    1.360000   72.790000    0.555000
# 75%      1.519157   13.825000    3.600000    1.630000   73.087500    0.610000
# max      1.533930   17.380000    4.490000    3.500000   75.410000    6.210000
#
#                Ca          Ba          Fe        Type
# count  214.000000  214.000000  214.000000  214.000000
# mean     8.956963    0.175047    0.057009    2.780374
# std      1.423153    0.497219    0.097439    2.103739
# min      5.430000    0.000000    0.000000    1.000000
# 25%      8.240000    0.000000    0.000000    1.000000
# 50%      8.600000    0.000000    0.000000    2.000000
# 75%      9.172500    0.000000    0.100000    3.000000
# max     16.190000    3.150000    0.510000    7.000000

# %% [markdown]
# From the above output We can infer that
#
#     - There are no null values in the data set
#     - In Al, Ca, Ba, Fe and Type Columns the mean is greater than median (50%) therefore the data will be skewed towards right
#     - In RI, Na column the mean is almost equal to the median(50%) therefore the data will be normally distributed
#     - In columns like Mg, Si, K, mean is lower than median and therefore the data is skewed toward left
#     - There is huge difference between the 75% and the maximum value in K, Ca, Ba and Fe columns and so the outliers will be there in the dataset

# %%
#COUNT OF SURVIVED AND NOT SURVIVED
plt.figure(figsize=(6,6))
Type=['BUILDING-FLOAT PROCESSED','BUILDING-NON FLOAT PROCESSED','VEHICLE-FLOAT PROCESSED','CONTAINERS','TABLEWARES','HEADLAMPS']
share=[70,76,17,13,9,29]
colors=['orange','green','blue','red','black','yellow']
plt.style.use('ggplot')
plt.title('COUNT FOR GLASS TYPE')
plt.pie(x=share,labels=Type,colors=colors,autopct='%.1f',startangle=90)
circle=plt.Circle(xy=(0,0), radius=0.75, facecolor='white')
plt.gca().add_artist(circle)
plt.show()

# %% [markdown]
# Therefore majority of the glass in the dataset belongs to building float processed and building non float processed and this is the imbalanced dataset

# %%
#DISTRIBUTION OF REFRACTIVE INDEX
plt.figure(figsize=(6,6))
sns.distplot(ds1['RI'])
plt.title('DISTRIBUTION OF REFRACTIVE INDEX')
plt.show()

# %% [markdown]
# Most of the values of RI lies between 1.51 and 1.52 and the data is skewed toward right

# %%
#DISTRIBUTION OF SODIUM CONTENT
plt.figure(figsize=(6,6))
sns.distplot(ds1['Na'])
plt.title('DISTRIBUTION OF SODIUM CONTENT')
plt.show()

# %% [markdown]
# Most of the values of Na lies between 12 and 15 and the data is almost normally distributed

# %%
#DISTRIBUTION OF CALCIUM CONTENT
plt.figure(figsize=(6,6))
sns.distplot(ds1['Ca'])
plt.title('DISTRIBUTION OF CALCIUM CONTENT')
plt.show()

# %% [markdown]
# Most of the values of Ca lies between 8 and 10 and the data is almost normally distributed

# %%
sns.pairplot(ds1,palette="spring_r")
plt.show()

# %%
#CHECKING FOR OUTLIERS
ds1.plot(kind='box',subplots=True,figsize=(10,10),layout=(3,4))
# Out:
# RI         AxesSubplot(0.125,0.653529;0.168478x0.226471)
# Na      AxesSubplot(0.327174,0.653529;0.168478x0.226471)
# Mg      AxesSubplot(0.529348,0.653529;0.168478x0.226471)
# Al      AxesSubplot(0.731522,0.653529;0.168478x0.226471)
# Si         AxesSubplot(0.125,0.381765;0.168478x0.226471)
# K       AxesSubplot(0.327174,0.381765;0.168478x0.226471)
# Ca      AxesSubplot(0.529348,0.381765;0.168478x0.226471)
# Ba      AxesSubplot(0.731522,0.381765;0.168478x0.226471)
# Fe             AxesSubplot(0.125,0.11;0.168478x0.226471)
# Type        AxesSubplot(0.327174,0.11;0.168478x0.226471)
# dtype: object

# %%
#CHECKING FOR OUTLIERS
from scipy.stats import zscore
z=np.abs(zscore(ds1))
z
# Out:
#            RI        Na        Mg        Al        Si         K        Ca  \
# 0    0.872868  0.284953  1.254639  0.692442  1.127082  0.671705  0.145766
# 1    0.249333  0.591817  0.636168  0.170460  0.102319  0.026213  0.793734
# 2    0.721318  0.149933  0.601422  0.190912  0.438787  0.164533  0.828949
# 3    0.232831  0.242853  0.698710  0.310994  0.052974  0.112107  0.519052
# 4    0.312045  0.169205  0.650066  0.411375  0.555256  0.081369  0.624699
# ..        ...       ...       ...       ...       ...       ...       ...
# 209  0.704815  0.898681  1.865511  2.881125  0.052974  0.640968  0.157088
# 210  0.500178  1.856097  1.865511  1.094342  0.529374  0.763919  0.392276
# 211  0.754046  1.168721  1.865511  1.154570  0.995252  0.763919  0.364103
# 212  0.612399  1.193270  1.865511  0.993960  1.241133  0.763919  0.335931
# 213  0.414363  1.009152  1.865511  1.275028  0.917606  0.763919  0.237327
#
#            Ba        Fe      Type
# 0    0.352877  0.586451  0.848275
# 1    0.352877  0.586451  0.848275
# 2    0.352877  0.586451  0.848275
# 3    0.352877  0.586451  0.848275
# 4    0.352877  0.586451  0.848275
# ..        ...       ...       ...
# 209  1.783978  0.586451  2.010478
# 210  2.852405  0.586451  2.010478
# 211  2.953200  0.586451  2.010478
# 212  2.812087  0.586451  2.010478
# 213  3.013677  0.586451  2.010478
#
# [214 rows x 10 columns]

# %%
print(np.where(z>3))
# Out:
# (array([105, 106, 106, 106, 106, 106, 107, 107, 107, 110, 111, 112, 112,
#        131, 145, 162, 163, 163, 163, 171, 171, 172, 172, 174, 184, 184,
#        188, 189, 201, 201, 203, 207, 213], dtype=int64), array([6, 0, 1, 4, 6, 7, 0, 4, 6, 6, 6, 0, 6, 6, 8, 8, 3, 4, 7, 3, 5, 3,
#        5, 8, 1, 4, 4, 7, 4, 5, 7, 7, 7], dtype=int64))

# %%
#REMOVING OUTLIERS
ds11=ds1[(z<3).all(axis=1)]
ds11
# Out:
#           RI     Na    Mg    Al     Si     K    Ca    Ba   Fe  Type
# 0    1.52101  13.64  4.49  1.10  71.78  0.06  8.75  0.00  0.0     1
# 1    1.51761  13.89  3.60  1.36  72.73  0.48  7.83  0.00  0.0     1
# 2    1.51618  13.53  3.55  1.54  72.99  0.39  7.78  0.00  0.0     1
# 3    1.51766  13.21  3.69  1.29  72.61  0.57  8.22  0.00  0.0     1
# 4    1.51742  13.27  3.62  1.24  73.08  0.55  8.07  0.00  0.0     1
# ..       ...    ...   ...   ...    ...   ...   ...   ...  ...   ...
# 208  1.51640  14.37  0.00  2.74  72.85  0.00  9.45  0.54  0.0     7
# 209  1.51623  14.14  0.00  2.88  72.61  0.08  9.18  1.06  0.0     7
# 210  1.51685  14.92  0.00  1.99  73.06  0.00  8.40  1.59  0.0     7
# 211  1.52065  14.36  0.00  2.02  73.42  0.00  8.44  1.64  0.0     7
# 212  1.51651  14.38  0.00  1.94  73.61  0.00  8.48  1.57  0.0     7
#
# [194 rows x 10 columns]

# %%
#CHECKING FOR SKEWNESS
ds11.skew()
# Out:
# RI      0.952733
# Na      0.371482
# Mg     -1.528849
# Al      0.658259
# Si     -0.425450
# K       0.303175
# Ca      1.077962
# Ba      3.188587
# Fe      1.486479
# Type    1.284007
# dtype: float64

# %%
Right Skewness - RI, Al, Ca, Ba, Fe,
left Skewness - Mg

# %%
#REMOVING SKEWNESS USING CUBEROOT METHOD
ds11[['RI','Al','Ca','Ba','Fe']] = np.cbrt(ds11[['RI','Al','Ca','Ba','Fe']])
ds11.skew()
# Out:
# RI      0.946482
# Na      0.371482
# Mg     -1.528849
# Al     -0.776139
# Si     -0.425450
# K       0.303175
# Ca      0.431929
# Ba      1.923662
# Fe      0.772399
# Type    1.284007
# dtype: float64

# %%
#REMOVING SKEWNESS USING CUBEROOT METHOD
ds11[['Ba']] = np.cbrt(ds11[['Ba']])
ds11.skew()
# Out:
# RI      0.000000
# Na      0.371482
# Mg     -1.528849
# Al     -0.374978
# Si     -0.425450
# K       0.303175
# Ca      0.431929
# Ba      1.871447
# Fe      0.772399
# Type    1.284007
# dtype: float64

# %%
#REMOVING SKEWNESS USING CUBEROOT METHOD
ds11[['Fe']] = np.sqrt(ds11[['Fe']])
ds11.skew()
# Out:
# RI      0.000000
# Na      0.371482
# Mg     -1.528849
# Al     -0.374978
# Si     -0.425450
# K       0.303175
# Ca      0.431929
# Ba      1.871447
# Fe      0.754365
# Type    1.284007
# dtype: float64

# %%
#REMOVING SKEWNESS USING CUBEROOT METHOD
ds11['Mg'] = np.power(ds11['Mg'],3)
ds11.skew()
# Out:
# RI      0.000000
# Na      0.371482
# Mg     -0.371221
# Al     -0.374978
# Si     -0.425450
# K       0.303175
# Ca      0.431929
# Ba      1.871447
# Fe      0.754365
# Type    1.284007
# dtype: float64

# %%
ds11.corr()
# Out:
#             RI        Na        Mg        Al        Si         K        Ca  \
# RI    1.000000  0.050556  0.099791 -0.551754 -0.608867 -0.368230  0.689400
# Na    0.050556  1.000000 -0.318522  0.153264 -0.234718 -0.612183  0.016920
# Mg    0.099791 -0.318522  1.000000 -0.524610 -0.410095  0.321212 -0.397435
# Al   -0.551754  0.153264 -0.524610  1.000000  0.351605  0.101983 -0.269024
# Si   -0.608867 -0.234718 -0.410095  0.351605  1.000000  0.072579 -0.157524
# K    -0.368230 -0.612183  0.321212  0.101983  0.072579  1.000000 -0.535074
# Ca    0.689400  0.016920 -0.397435 -0.269024 -0.157524 -0.535074  1.000000
# Ba   -0.215327  0.480429 -0.478016  0.484005  0.179683 -0.268703 -0.120658
# Fe    0.030765 -0.118319  0.060199 -0.039267 -0.003755  0.012612  0.030834
# Type -0.167534  0.533025 -0.734409  0.591653  0.262152 -0.383499  0.129261
#
#             Ba        Fe      Type
# RI   -0.215327  0.030765 -0.167534
# Na    0.480429 -0.118319  0.533025
# Mg   -0.478016  0.060199 -0.734409
# Al    0.484005 -0.039267  0.591653
# Si    0.179683 -0.003755  0.262152
# K    -0.268703  0.012612 -0.383499
# Ca   -0.120658  0.030834  0.129261
# Ba    1.000000  0.058070  0.616972
# Fe    0.058070  1.000000 -0.146577
# Type  0.616972 -0.146577  1.000000

# %%
plt.figure(figsize=(15,6))
sns.heatmap(ds1.corr(),annot=True,linewidths=0.6,linecolor='black',fmt='0.2f')
plt.show()

# %%
#SEPERATING INDEPENDENT VARIABLES AND TARGET
x1 = ds11.drop('Type',axis=1)
y1 = ds11['Type']
print(x1)
# Out:
#            RI     Na          Mg        Al     Si     K        Ca   Ba   Fe
# 0    1.000192  13.64  406.429632  1.032280  71.78  0.06  1.272529  0.0  0.0
# 1    1.000191  13.89  167.961600  1.107932  72.73  0.48  1.256918  0.0  0.0
# 2    1.000190  13.53  158.823006  1.154800  72.99  0.39  1.256023  0.0  0.0
# 3    1.000191  13.21  185.398179  1.088587  72.61  0.57  1.263725  0.0  0.0
# 4    1.000191  13.27  171.725299  1.074337  73.08  0.55  1.261141  0.0  0.0
# ..        ...    ...         ...       ...    ...   ...       ...  ...  ...
# 208  1.000190  14.37    0.000000  1.399319  72.85  0.00  1.283457  1.0  0.0
# 209  1.000190  14.14    0.000000  1.422757  72.61  0.08  1.279330  1.0  0.0
# 210  1.000191  14.92    0.000000  1.257818  73.06  0.00  1.266770  1.0  0.0
# 211  1.000192  14.36    0.000000  1.264107  73.42  0.00  1.267439  1.0  0.0
# 212  1.000190  14.38    0.000000  1.247194  73.61  0.00  1.268105  1.0  0.0
#
# [194 rows x 9 columns]

# %%
y1
# Out:
# 0      1
# 1      1
# 2      1
# 3      1
# 4      1
#       ..
# 208    7
# 209    7
# 210    7
# 211    7
# 212    7
# Name: Type, Length: 194, dtype: int64

# %%
#SCALING TO REMOVE BIASNESS - STANDARD SCALING
from sklearn.preprocessing import StandardScaler
st=StandardScaler()
x1=st.fit_transform(x1)
x1
# Out:
# array([[ 1.29219167,  0.33212692,  3.74826335, ..., -0.02929614,
#         -0.43610096, -0.6934811 ],
#        [-0.19725014,  0.70439768,  0.5680768 , ..., -1.04527386,
#         -0.43610096, -0.6934811 ],
#        [-0.82468851,  0.16832779,  0.4462054 , ..., -1.10347956,
#         -0.43610096, -0.6934811 ],
#        ...,
#        [-0.53064028,  2.23815319, -1.67184281, ..., -0.40408944,
#          2.29304762, -0.6934811 ],
#        [ 1.13464368,  1.4042667 , -1.67184281, ..., -0.36056075,
#          2.29304764, -0.6934811 ],
#        [-0.67984255,  1.43404836, -1.67184281, ..., -0.31721504,
#          2.29304761, -0.6934811 ]])

# %%
x1=pd.DataFrame(data=x1)
x1
# Out:
#             0         1         2         3         4         5         6  \
# 0    1.292192  0.332127  3.748263 -0.666678 -1.612464 -1.319609 -0.029296
# 1   -0.197250  0.704398  0.568077 -0.035036  0.016082  0.172091 -1.045274
# 2   -0.824689  0.168328  0.446205  0.356287  0.461790 -0.147559 -1.103480
# 3   -0.175322 -0.308179  0.800609 -0.196550 -0.189629  0.491741 -0.602278
# 4   -0.280582 -0.218834  0.618269 -0.315529  0.616073  0.420708 -0.770404
# ..        ...       ...       ...       ...       ...       ...       ...
# 189 -0.728121  1.419158 -1.671843  2.397864  0.221793 -1.532708  0.681936
# 190 -0.802740  1.076668 -1.671843  2.593556 -0.189629 -1.248575  0.413335
# 191 -0.530640  2.238153 -1.671843  1.216416  0.581788 -1.532708 -0.404089
# 192  1.134644  1.404267 -1.671843  1.268927  1.198921 -1.532708 -0.360561
# 193 -0.679843  1.434048 -1.671843  1.127713  1.524630 -1.532708 -0.317215
#
#             7         8
# 0   -0.436101 -0.693481
# 1   -0.436101 -0.693481
# 2   -0.436101 -0.693481
# 3   -0.436101 -0.693481
# 4   -0.436101 -0.693481
# ..        ...       ...
# 189  2.293047 -0.693481
# 190  2.293047 -0.693481
# 191  2.293048 -0.693481
# 192  2.293048 -0.693481
# 193  2.293048 -0.693481
#
# [194 rows x 9 columns]

# %%
from statsmodels.stats.outliers_influence import variance_inflation_factor
vif = pd.DataFrame()
vif["VIF Factor"] = [variance_inflation_factor(x1.values, i) for i in range(x1.shape[1])]
vif["features"] = x1.columns
vif
# Out:
#    VIF Factor  features
# 0    4.841705         0
# 1    4.523657         1
# 2    5.600131         2
# 3    2.718063         3
# 4    3.757442         4
# 5    4.160443         5
# 6    6.790894         6
# 7    2.015212         7
# 8    1.056095         8

# %% [markdown]
# From the above data frame it is clear that the dataset is free from multicolinearity problem

# %%
y1.value_counts()
# Out:
# 1    70
# 2    68
# 7    23
# 3    16
# 5     9
# 6     8
# Name: Type, dtype: int64

# %%
#BALANCING THE DATA SET
from imblearn.over_sampling import SMOTE
SM=SMOTE()
x1,y1=SM.fit_resample(x1,y1)
y1.value_counts()
# Out:
# 1    70
# 2    70
# 3    70
# 5    70
# 6    70
# 7    70
# Name: Type, dtype: int64

# %% [markdown]
# MODELLING

# %%
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import accuracy_score
from sklearn.metrics import confusion_matrix
from sklearn.metrics import classification_report
from sklearn.metrics import roc_curve
from sklearn.model_selection import cross_val_score

# %%
x1_train,x1_test,y1_train,y1_test=train_test_split(x1,y1,test_size=0.30,random_state=42)

# %%
print(x1_train.shape)
print(y1_train.shape)
print(x1_test.shape)
print(y1_test.shape)
# Out:
# (294, 9)
# (294,)
# (126, 9)
# (126,)

# %%
m1=LogisticRegression()
m1.fit(x1_train,y1_train)
testprediction1=m1.predict(x1_test)
print(accuracy_score(y1_test,testprediction1))
print(confusion_matrix(y1_test,testprediction1))
print(classification_report(y1_test,testprediction1))
score1=cross_val_score(m1,x1,y1)
print(score1)
print(score1.mean())
print(((accuracy_score(y1_test,testprediction1))-score1.mean()))
# Out:
# 0.7222222222222222
# [[12  9  6  0  0  0]
#  [ 1 10 10  2  1  1]
#  [ 3  1 12  0  0  0]
#  [ 0  0  0 16  0  0]
#  [ 0  0  0  0 23  0]
#  [ 1  0  0  0  0 18]]
#               precision    recall  f1-score   support
#
#            1       0.71      0.44      0.55        27
#            2       0.50      0.40      0.44        25
#            3       0.43      0.75      0.55        16
#            5       0.89      1.00      0.94        16
#            6       0.96      1.00      0.98        23
#            7       0.95      0.95      0.95        19
#
#     accuracy                           0.72       126
#    macro avg       0.74      0.76      0.73       126
# weighted avg       0.74      0.72      0.72       126
#
# [0.79761905 0.76190476 0.85714286 0.79761905 0.83333333]
# 0.8095238095238095
# -0.08730158730158732

# %%
from sklearn.ensemble import RandomForestClassifier
m2=RandomForestClassifier()
m2.fit(x1_train,y1_train)
testprediction2=m2.predict(x1_test)
print(accuracy_score(y1_test,testprediction2))
print(confusion_matrix(y1_test,testprediction2))
print(classification_report(y1_test,testprediction2))
score2=cross_val_score(m2,x1,y1)
print(score2)
print(score2.mean())
print(((accuracy_score(y1_test,testprediction2))-score2.mean()))
# Out:
# 0.873015873015873
# [[20  3  4  0  0  0]
#  [ 3 20  1  1  0  0]
#  [ 3  0 13  0  0  0]
#  [ 0  0  0 16  0  0]
#  [ 0  0  0  0 23  0]
#  [ 1  0  0  0  0 18]]
#               precision    recall  f1-score   support
#
#            1       0.74      0.74      0.74        27
#            2       0.87      0.80      0.83        25
#            3       0.72      0.81      0.76        16
#            5       0.94      1.00      0.97        16
#            6       1.00      1.00      1.00        23
#            7       1.00      0.95      0.97        19
#
#     accuracy                           0.87       126
#    macro avg       0.88      0.88      0.88       126
# weighted avg       0.88      0.87      0.87       126
#
# [0.88095238 0.86904762 0.86904762 0.83333333 0.91666667]
# 0.8738095238095239
# -0.0007936507936509019

# %%
from sklearn.ensemble import ExtraTreesClassifier
m3=ExtraTreesClassifier()
m3.fit(x1_train,y1_train)
testprediction3=m3.predict(x1_test)
print(accuracy_score(y1_test,testprediction3))
print(confusion_matrix(y1_test,testprediction3))
print(classification_report(y1_test,testprediction3))
score3=cross_val_score(m3,x1,y1)
print(score3)
print(score3.mean())
print(((accuracy_score(y1_test,testprediction3))-score3.mean()))
# Out:
# 0.8888888888888888
# [[19  4  4  0  0  0]
#  [ 2 22  0  1  0  0]
#  [ 3  0 13  0  0  0]
#  [ 0  0  0 16  0  0]
#  [ 0  0  0  0 23  0]
#  [ 0  0  0  0  0 19]]
#               precision    recall  f1-score   support
#
#            1       0.79      0.70      0.75        27
#            2       0.85      0.88      0.86        25
#            3       0.76      0.81      0.79        16
#            5       0.94      1.00      0.97        16
#            6       1.00      1.00      1.00        23
#            7       1.00      1.00      1.00        19
#
#     accuracy                           0.89       126
#    macro avg       0.89      0.90      0.89       126
# weighted avg       0.89      0.89      0.89       126
#
# [0.91666667 0.8452381  0.86904762 0.80952381 0.92857143]
# 0.8738095238095239
# 0.015079365079364915

# %%
from sklearn.ensemble import GradientBoostingClassifier
m4=GradientBoostingClassifier()
m4.fit(x1_train,y1_train)
testprediction4=m4.predict(x1_test)
print(accuracy_score(y1_test,testprediction4))
print(confusion_matrix(y1_test,testprediction4))
print(classification_report(y1_test,testprediction4))
score4=cross_val_score(m4,x1,y1)
print(score4)
print(score4.mean())
print(((accuracy_score(y1_test,testprediction4))-score4.mean()))
# Out:
# 0.9047619047619048
# [[22  2  3  0  0  0]
#  [ 3 21  1  0  0  0]
#  [ 1  1 14  0  0  0]
#  [ 0  0  0 16  0  0]
#  [ 0  0  0  0 23  0]
#  [ 1  0  0  0  0 18]]
#               precision    recall  f1-score   support
#
#            1       0.81      0.81      0.81        27
#            2       0.88      0.84      0.86        25
#            3       0.78      0.88      0.82        16
#            5       1.00      1.00      1.00        16
#            6       1.00      1.00      1.00        23
#            7       1.00      0.95      0.97        19
#
#     accuracy                           0.90       126
#    macro avg       0.91      0.91      0.91       126
# weighted avg       0.91      0.90      0.91       126
#
# [0.9047619  0.86904762 0.86904762 0.83333333 0.88095238]
# 0.8714285714285716
# 0.033333333333333215

# %%
from sklearn.ensemble import AdaBoostClassifier
m5=AdaBoostClassifier()
m5.fit(x1_train,y1_train)
testprediction5=m5.predict(x1_test)
print(accuracy_score(y1_test,testprediction5))
print(confusion_matrix(y1_test,testprediction5))
print(classification_report(y1_test,testprediction5))
score5=cross_val_score(m5,x1,y1)
print(score5)
print(score5.mean())
print(((accuracy_score(y1_test,testprediction5))-score5.mean()))
# Out:
# 0.4603174603174603
# [[ 0  0 26  0  1  0]
#  [ 0  1 24  0  0  0]
#  [ 0  0 16  0  0  0]
#  [ 0 16  0  0  0  0]
#  [ 0  0  0  0 23  0]
#  [ 0  0  1  0  0 18]]
#               precision    recall  f1-score   support
#
#            1       0.00      0.00      0.00        27
#            2       0.06      0.04      0.05        25
#            3       0.24      1.00      0.39        16
#            5       0.00      0.00      0.00        16
#            6       0.96      1.00      0.98        23
#            7       1.00      0.95      0.97        19
#
#     accuracy                           0.46       126
#    macro avg       0.38      0.50      0.40       126
# weighted avg       0.37      0.46      0.38       126
#
# [0.47619048 0.5        0.5        0.36904762 0.38095238]
# 0.44523809523809527
# 0.015079365079365026

# %%
from sklearn.ensemble import BaggingClassifier
m6=BaggingClassifier()
m6.fit(x1_train,y1_train)
testprediction6=m6.predict(x1_test)
print(accuracy_score(y1_test,testprediction6))
print(confusion_matrix(y1_test,testprediction6))
print(classification_report(y1_test,testprediction6))
score6=cross_val_score(m6,x1,y1)
print(score6)
print(score6.mean())
print(((accuracy_score(y1_test,testprediction6))-score6.mean()))
# Out:
# 0.8571428571428571
# [[19  2  6  0  0  0]
#  [ 4 20  1  0  0  0]
#  [ 5  0 11  0  0  0]
#  [ 0  0  0 16  0  0]
#  [ 0  0  0  0 23  0]
#  [ 0  0  0  0  0 19]]
#               precision    recall  f1-score   support
#
#            1       0.68      0.70      0.69        27
#            2       0.91      0.80      0.85        25
#            3       0.61      0.69      0.65        16
#            5       1.00      1.00      1.00        16
#            6       1.00      1.00      1.00        23
#            7       1.00      1.00      1.00        19
#
#     accuracy                           0.86       126
#    macro avg       0.87      0.87      0.86       126
# weighted avg       0.86      0.86      0.86       126
#
# [0.8452381  0.83333333 0.86904762 0.80952381 0.88095238]
# 0.8476190476190475
# 0.009523809523809601

# %%
from sklearn.svm import SVC
m7=SVC()
m7.fit(x1_train,y1_train)
testprediction7=m7.predict(x1_test)
print(accuracy_score(y1_test,testprediction7))
print(confusion_matrix(y1_test,testprediction7))
print(classification_report(y1_test,testprediction7))
score7=cross_val_score(m7,x1,y1)
print(score7)
print(score7.mean())
print(((accuracy_score(y1_test,testprediction7))-score7.mean()))
# Out:
# 0.8015873015873016
# [[13  7  7  0  0  0]
#  [ 2 20  2  1  0  0]
#  [ 2  2 12  0  0  0]
#  [ 0  0  0 16  0  0]
#  [ 0  0  0  0 23  0]
#  [ 1  1  0  0  0 17]]
#               precision    recall  f1-score   support
#
#            1       0.72      0.48      0.58        27
#            2       0.67      0.80      0.73        25
#            3       0.57      0.75      0.65        16
#            5       0.94      1.00      0.97        16
#            6       1.00      1.00      1.00        23
#            7       1.00      0.89      0.94        19
#
#     accuracy                           0.80       126
#    macro avg       0.82      0.82      0.81       126
# weighted avg       0.81      0.80      0.80       126
#
# [0.77380952 0.83333333 0.86904762 0.83333333 0.8452381 ]
# 0.830952380952381
# -0.029365079365079372

# %%
from sklearn.tree import DecisionTreeClassifier
m8=DecisionTreeClassifier()
m8.fit(x1_train,y1_train)
testprediction8=m8.predict(x1_test)
print(accuracy_score(y1_test,testprediction8))
print(confusion_matrix(y1_test,testprediction8))
print(classification_report(y1_test,testprediction8))
score8=cross_val_score(m8,x1,y1)
print(score8)
print(score8.mean())
print(((accuracy_score(y1_test,testprediction8))-score8.mean()))
# Out:
# 0.8492063492063492
# [[21  4  2  0  0  0]
#  [ 7 17  1  0  0  0]
#  [ 5  0 11  0  0  0]
#  [ 0  0  0 16  0  0]
#  [ 0  0  0  0 23  0]
#  [ 0  0  0  0  0 19]]
#               precision    recall  f1-score   support
#
#            1       0.64      0.78      0.70        27
#            2       0.81      0.68      0.74        25
#            3       0.79      0.69      0.73        16
#            5       1.00      1.00      1.00        16
#            6       1.00      1.00      1.00        23
#            7       1.00      1.00      1.00        19
#
#     accuracy                           0.85       126
#    macro avg       0.87      0.86      0.86       126
# weighted avg       0.86      0.85      0.85       126
#
# [0.83333333 0.8452381  0.8452381  0.82142857 0.83333333]
# 0.8357142857142856
# 0.013492063492063555

# %% [markdown]
# Therefore from the above models RANDOM FOREST CLASSIFIER has been selected as the best model for this problem based on the ACCURACY SCORE and the cross validation score

# %%
from sklearn.model_selection import GridSearchCV
parameters={'criterion':['gini','entropy','log_loss'],'n_jobs':[-1,1],'max_features':['sqrt','log2'],'bootstrap':[True,False]}
gridsearchcv=GridSearchCV(RandomForestClassifier(),parameters,cv=5)
gridsearchcv.fit(x1_train,y1_train)
# Out:
# GridSearchCV(cv=5, estimator=RandomForestClassifier(),
#              param_grid={'bootstrap': [True, False],
#                          'criterion': ['gini', 'entropy', 'log_loss'],
#                          'max_features': ['sqrt', 'log2'], 'n_jobs': [-1, 1]})

# %%
gridsearchcv.best_params_
# Out:
# {'bootstrap': True,
#  'criterion': 'entropy',
#  'max_features': 'log2',
#  'n_jobs': -1}

# %%
best_model=RandomForestClassifier(bootstrap=True,criterion='entropy',max_features='log2',n_jobs=-1)
best_model.fit(x1_train,y1_train)
prediction=best_model.predict(x1_test)
accuracy=accuracy_score(y1_test,prediction)
print(accuracy)
# Out:
# 0.8571428571428571

# %%
def predict(glass_type):
    glass_type=glass_type.reshape(1,-1)
    pred=best_model.predict(glass_type)
    print("PREDICTED VALUE:",pred)
    if pred==1:
        print("BUILDING WINDOW-FLOAT PROCESSED")
    elif pred==2:
        print("BUILDING WINDOW - NON FLOAT PROCESSED")
    elif pred==3:
        print("VEHICLE WINDOW - FLOAT PROCESSED")
    elif pred==5:
        print("CONTAINERS")
    elif pred==6:
        print("TABLEWARES")
    elif pred==7:
        print("HEADLAMPS")
glass_type=np.array([-0.728121,1.419158,-1.671843,2.397864,0.221793,-1.532708,0.681936,2.293047,-0.693481])
predict(glass_type)
# Out:
# PREDICTED VALUE: [7]
# HEADLAMPS
